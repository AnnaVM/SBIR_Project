# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cd code
# Out:
# /Users/AnnaVMS/Desktop/Galvanize/SBIR-project/code

# %%
from prepare_data import subset_data
from roc import ROC

# %%
cd ../
# Out:
# /Users/AnnaVMS/Desktop/Galvanize/SBIR-project

# %%
df = subset_data('dod', 2012, '/Users/AnnaVMS/Desktop/test2')
# Out:
# ['2015-12-14_award_export_10001TO15000.csv', '2015-12-14_award_export_1TO5000.csv', '2015-12-14_award_export_5001TO10000.csv']
# prepare_data.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plot_roc = ROC(df)

# %%
plot_roc.plot_LogReg(penalty='l1', C=0.1)
plot_roc.plot_RF(color='red', n_estimators=100)

# %%
plot_roc = ROC(df)
colors = ['red', 'blue', 'orange', 'green', 'black']
n_estimators = [2, 10, 100, 200, 1000]
for i in xrange(5):
    plot_roc.plot_RF(color=colors[i], n_estimators=n_estimators[i])

# %%
plot_roc = ROC(df)
colors = ['red', 'blue', 'orange', 'green', 'black']
n_estimators = [2, 10, 100, 200, 1000]
for i in xrange(5):
    plot_roc.plot_GB(color=colors[i], n_estimators=n_estimators[i])

# %%
plot_roc = ROC(df)
colors = ['red', 'blue', 'orange', 'green', 'black']
learning_rate = [0.01, 0.1, 1, 10]
for i in xrange(4):
    plot_roc.plot_GB(color=colors[i], learning_rate=learning_rate[i])

# %%
plot_roc = ROC(df)
colors = ['red', 'blue', 'orange', 'green', 'black']
C = [0.01, 0.1, 1, 10]
for i in xrange(4):
    plot_roc.plot_SVM(color=colors[i], C=C[i])

# %%
plot_roc = ROC(df)
plot_roc.plot_LogReg(color='green')
plot_roc.plot_RF(color='blue', n_estimators=200)
plot_roc.plot_GB(color='red', learning_rate=0.1)
plot_roc.plot_SVM(color='orange')

# %%
plot_roc = ROC(df)
plot_roc.plot_LogReg(color='green')
plot_roc.plot_RF(color='blue', n_estimators=200)
plot_roc.plot_GB(color='red', learning_rate=0.1)
plot_roc.plot_SVM(color='orange')

# %%
plot_roc = ROC(df)
plot_roc.plot_LogReg(color='green')
plot_roc.plot_RF(color='blue', n_estimators=200)
plot_roc.plot_GB(color='red', learning_rate=0.1)
plot_roc.plot_SVM(color='orange')
